# %% [markdown]
# # Least square problem for polynomial regression

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.image as img
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %% [markdown]
# ## load data points
# - $\{ (x_i, y_i) \}_{i=1}^n$

# %%
filename    = 'assignment_05_data.csv'
data        = np.loadtxt(filename, delimiter = ',')

x           = data[0, :]    # independent variable
y           = data[1, :]    # dependent variable

x_sample    = x[::10]       
y_sample    = y[::10]

plt.figure(figsize=(16,6))

plt.subplot(121)
plt.plot(x, y, '-', color = 'blue')
plt.title('data points')

plt.subplot(122)
plt.plot(x, y, '-', color = 'blue')
plt.plot(x_sample, y_sample, 'o', color = 'red')
plt.title('samples of data points (every 10 points)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## solve a linear system of equation $A z = b$
# $$
# A =
# \begin{bmatrix}
# x_1^0 & x_1^1 & \cdots & x_1^{p-1}\\
# x_2^0 & x_2^1 & \cdots & x_2^{p-1}\\
# \vdots & \vdots & \vdots & \vdots\\
# x_n^0 & x_n^1 & \cdots & x_n^{p-1}
# \end{bmatrix},
# \quad
# z =
# \begin{bmatrix}
# \theta_0\\
# \theta_1\\
# \vdots\\
# \theta_{p-1}
# \end{bmatrix},
# \quad
# b =
# \begin{bmatrix}
# y_1\\
# y_2\\
# \vdots\\
# y_n
# \end{bmatrix}
# $$

# %% [markdown]
# ## construct matrix A for the polynomial regression with power $p-1$
# - useful functions : `np.power`

# %%
def construct_matrix_A(x, p):
    
    n = len(x)
    A = np.zeros([n, p])
    
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    for i in range(1, n):
        for j in range(p):
            A[i-1][j]=np.power(x[i-1],[j])

    #for문 안쓰고 만드는 법 찾기
    # square = np.arange(p)    #p[0,1,2,3,4,5,6,7,8,...,p-1]
    # for i in range (n):
    #     A = np.power(x[i],square)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return A

# %% [markdown]
# ## construct vector $b$

# %%
def construct_vector_b(y):

    n = len(y)
    b = np.zeros([n, 1])

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    b=y.reshape(-1,1)
    
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return b

# %% [markdown]
# ## solve the linear system of equation $A z = b$
# - without regularization : $\min \frac{1}{2 n}\| Az - b \|^2, \quad z = \left( A^T A \right)^{-1} A^T b$
# - useful functions : `np.matmul, np.linalg.inv, np.sum`

# %%
def solve_regression(x, y, p):

    z       = np.zeros([p, 1])
    loss    = 0

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    # 맞는지 확인하기
    ATA = np.matmul(construct_matrix_A(x,p).T, construct_matrix_A(x,p))
    inv_ATA = np.linalg.inv(ATA)
    z_temp = np.matmul(inv_ATA, construct_matrix_A(x,p).T)
    z=np.matmul(z_temp,construct_vector_b(y))
    L2 = np.matmul(construct_matrix_A(x,p), z)-construct_vector_b(y)
    L2norm = np.linalg.norm(L2)
    L2norm_square = np.power(L2norm, 2)
    loss = np.sum(L2norm_square)/(2*len(x))
    

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return z, loss

# %% [markdown]
# - with regularization : $\min \frac{1}{2 n} \| A z - b \|^2 + \frac{\alpha}{2} \| z \|^2, \quad z = \left(A^{T} A + n \alpha I \right)^{-1} A^T b$ where $I$ denotes identity matrix
# - useful functions : `np.matmul, np.linalg.inv, np.sum`

# %%
def solve_regression_with_regularization(x, y, p, alpha):

    z       = np.zeros([p, 1])
    loss    = 0

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    n=len(x)
    matmul = np.matmul(construct_matrix_A(x,p).T, construct_matrix_A(x,p))
    naI = n*alpha*np.eye(n)
    z=np.matmul(np.matmul(np.linalg.inv(matmul+naI),construct_matrix_A(x,p).T),construct_vector_b(y))
    
    #loss
    L2 = np.matmul(construct_matrix_A(x,p), z)-construct_vector_b(y)
    L2norm = np.linalg.norm(L2)
    L2norm_square = np.power(L2norm, 2)
    lossL2 = np.sum(L2norm_square)/(2*len(x))
    znorm = np.linalg.norm(z)
    znorm_square = np.power(znorm,2)
    loss_znorm = np.sum(znorm_square)*alpha/2
    loss = lossL2+loss_znorm
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return z, loss

# %% [markdown]
# ## approximate by polynomial regression
# - $ \hat{y} = A z^* $
# - useful functions : `np.matmul`

# %%
def approximate(x, y, p):

    n       = len(y)
    y_hat   = np.zeros([n, 1])
    loss    = 0

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #y_hat = Az*
    
    reg_z, reg_loss = solve_regression(x,y,p) 
    y_hat = np.matmul(construct_matrix_A(x,p), reg_z)
    loss = reg_loss
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return y_hat, loss

# %%
def approximate_with_regularization(x, y, p, alpha):
    
    n       = len(y)
    y_hat   = np.zeros([n, 1])
    loss    = 0

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    reg_reg_z, reg_reg_loss = solve_regression_with_regularization(x,y,p,alpha)
    y_hat = np.matmul(construct_matrix_A(x,p), reg_reg_z)
    loss = reg_reg_loss
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return y_hat, loss

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
def function_result_01():
    
    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.title('data points')
    plt.show()

# %%
def function_result_02():

    p           = 2
    (y_hat, _)  = approximate(x, y, p)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_03():

    p           = 4
    (y_hat, _)  = approximate(x, y, p)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_04():

    p           = 8
    (y_hat, _)  = approximate(x, y, p)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_05():

    p           = 16
    (y_hat, _)  = approximate(x, y, p)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_06():

    p           = 32 
    (y_hat, _)  = approximate(x, y, p)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_07():

    p           = 2 
    alpha       = 0.1
    (y_hat, _)  = approximate_with_regularization(x, y, p, alpha)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_08():

    p           = 4 
    alpha       = 0.1
    (y_hat, _)  = approximate_with_regularization(x, y, p, alpha)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_09():

    p           = 8 
    alpha       = 0.1
    (y_hat, _)  = approximate_with_regularization(x, y, p, alpha)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_10():

    p           = 16 
    alpha       = 0.1
    (y_hat, _)  = approximate_with_regularization(x, y, p, alpha)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_11():

    p           = 32 
    alpha       = 0.1
    (y_hat, _)  = approximate_with_regularization(x, y, p, alpha)

    plt.figure(figsize=(8,6))
    plt.plot(x, y, '-', color='blue')
    plt.plot(x, y_hat, '-', color='red')
    plt.show()

# %%
def function_result_12():

    p           = 4
    (_, loss)   = approximate(x, y, p)

    print('loss = ', loss)

# %%
def function_result_13():

    p           = 16
    (_, loss)   = approximate(x, y, p)

    print('loss = ', loss)

# %%
def function_result_14():

    p           = 4
    alpha       = 0.1
    (_, loss)   = approximate_with_regularization(x, y, p, alpha)

    print('loss = ', loss)

# %%
def function_result_15():

    p           = 16 
    alpha       = 0.1
    (_, loss)   = approximate_with_regularization(x, y, p, alpha)

    print('loss = ', loss)

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
number_result = 15

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# **************************************************
# ## [RESULT 02]
# **************************************************
# **************************************************
# ## [RESULT 03]
# **************************************************
# **************************************************
# ## [RESULT 04]
# **************************************************
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# **************************************************
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\rlatn\Desktop\4-1\machine learning\class\machine-learning\05\assignment_05.ipynb Cell 43' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000042?line=7'>8</a> print(title)
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000042?line=8'>9</a> print('**************************************************')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000042?line=9'>10</a> eval(name_function)
#
# File <string>:1, in <module>
#
# c:\Users\rlatn\Desktop\4-1\machine learning\class\machine-learning\05\assignment_05.ipynb Cell 29' in function_result_07()
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000028?line=2'>3</a> p           = 2
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000028?line=3'>4</a> alpha       = 0.1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000028?line=4'>5</a> (y_hat, _)  = approximate_with_regularization(x, y, p, alpha)
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000028?line=6'>7</a> plt.figure(figsize=(8,6))
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000028?line=7'>8</a> plt.plot(x, y, '-', color='blue')
#
# c:\Users\rlatn\Desktop\4-1\machine learning\class\machine-learning\05\assignment_05.ipynb Cell 17' in approximate_with_regularization(x, y, p, alpha)
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000016?line=4'>5</a> loss    = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000016?line=6'>7</a> # ++++++++++++++++++++++++++++++++++++++++++++++++++
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000016?line=7'>8</a> # complete the blanks
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000016?line=8'>9</a> #
# ---> <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000016?line=9'>10</a> reg_reg_z, reg_reg_loss = solve_regression_with_regularization(x,y,p,alpha)
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000016?line=10'>11</a> y_hat = np.matmul(construct_matrix_A(x,p), reg_reg_z)
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000016?line=11'>12</a> loss = reg_reg_loss
#
# c:\Users\rlatn\Desktop\4-1\machine learning\class\machine-learning\05\assignment_05.ipynb Cell 14' in solve_regression_with_regularization(x, y, p, alpha)
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000013?line=9'>10</a> matmul = np.matmul(construct_matrix_A(x,p).T, construct_matrix_A(x,p))
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000013?line=10'>11</a> naI = n*alpha*np.eye(n)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000013?line=11'>12</a> z=np.matmul(np.matmul(np.linalg.inv(matmul+naI),construct_matrix_A(x,p).T),construct_vector_b(y))
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000013?line=13'>14</a> #loss
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/05/assignment_05.ipynb#ch0000013?line=14'>15</a> L2 = np.matmul(construct_matrix_A(x,p), z)-construct_vector_b(y)
#
# ValueError: operands could not be broadcast together with shapes (2,2) (1000,1000)
