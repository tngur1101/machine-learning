# %% [markdown]
# # Logistic Regression with non-linear features

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import ticker, cm

# %% [markdown]
# ## load training data

# %%
fname_data1 = 'assignment_09_data1.txt'
fname_data2 = 'assignment_09_data2.txt'

data1        = np.genfromtxt(fname_data1, delimiter=',')
data2        = np.genfromtxt(fname_data2, delimiter=',')

number_data1 = data1.shape[0]
number_data2 = data2.shape[0]

data1_point     = data1[:, 0:2]
data1_point_x   = data1_point[:, 0]
data1_point_y   = data1_point[:, 1]
data1_label     = data1[:, 2]

data2_point     = data2[:, 0:2]
data2_point_x   = data2_point[:, 0]
data2_point_y   = data2_point[:, 1]
data2_label     = data2[:, 2]

data1_label_class_0     = (data1_label == 0)
data1_label_class_1     = (data1_label == 1)

data2_label_class_0     = (data2_label == 0)
data2_label_class_1     = (data2_label == 1)

data1_point_x_class_0   = data1_point_x[data1_label_class_0]
data1_point_y_class_0   = data1_point_y[data1_label_class_0]

data1_point_x_class_1   = data1_point_x[data1_label_class_1]
data1_point_y_class_1   = data1_point_y[data1_label_class_1]

data2_point_x_class_0   = data2_point_x[data2_label_class_0]
data2_point_y_class_0   = data2_point_y[data2_label_class_0]

data2_point_x_class_1   = data2_point_x[data2_label_class_1]
data2_point_y_class_1   = data2_point_y[data2_label_class_1]

print('shape of point in data1 = ', data1_point.shape)
print('shape of point in data2 = ', data2_point.shape)

print('shape of label in data1 = ', data1_label.shape)
print('shape of label in data2 = ', data2_label.shape)

print('data type of point x in data1 = ', data1_point_x.dtype)
print('data type of point y in data1 = ', data1_point_y.dtype)

print('data type of point x in data2 = ', data2_point_x.dtype)
print('data type of point y in data2 = ', data2_point_y.dtype)
# Out:
# shape of point in data1 =  (1000, 2)
# shape of point in data2 =  (1000, 2)
# shape of label in data1 =  (1000,)
# shape of label in data2 =  (1000,)
# data type of point x in data1 =  float64
# data type of point y in data1 =  float64
# data type of point x in data2 =  float64
# data type of point y in data2 =  float64

# %% [markdown]
# ## plot the data

# %%
f = plt.figure(figsize=(8,8))   

plt.title('points in data1')
plt.plot(data1_point_x_class_0, data1_point_y_class_0, 'o', color='blue', label='class = 0')
plt.plot(data1_point_x_class_1, data1_point_y_class_1, 'o', color='red', label='class = 1')
plt.axis('equal')
plt.legend()
plt.tight_layout()
plt.show()

# %%
f = plt.figure(figsize=(8,8))   

plt.title('points in data2')
plt.plot(data2_point_x_class_0, data2_point_y_class_0, 'o', color='blue', label='class = 0')
plt.plot(data2_point_x_class_1, data2_point_y_class_1, 'o', color='red', label='class = 1')
plt.axis('equal')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## define the feature functions

# %% [markdown]
# - feature vector is defined by $(1, f_1(x, y), f_2(x, y), \cdots, f_{k-1}(x, y)) \in \mathbb{R}^k$

# %%
def compute_feature1(point):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    #point는 (x,y)로 들어옴
    #내가 해야할건 theta랑 곱할 애 matrix를 만들어줘야함
    #f(theta, x,y)=theta0+theta1*x1+theta2*y1+theta3*x1^2+theta4*y1^2
    #theta=[theta0, theta1, theta2, theta3, theta4]
    #feature은 [1,x1,y1,x1^2,y1^2]과 같은 형식이 들어가야함
    # [1,x1, y1, x1^2, y1^2, x1^2*y1, x1*y1^2]
    # [x1^2, y1^2, sqrt(2)*x1*y1]
    # k(x,y)=(x.Ty)^2
    
    x1=point[:, 0]
    y1=point[:, 1]
    feature = np.c_[np.ones(len(point)),x1**2,y1**2,np.sqrt(2)*x1*y1]
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return feature

# %%
def compute_feature2(point):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    #[1,x1,y1,x1^2,y1^2, x1^2*y1, x1*y1^2, x1^3, y1^3, x1^3*y1, x1*y1^3]
    # [x1,x2].T= [x1^5, x1^4x2, x1^3x2^2, x1^2x2^3,x1x2^4, x2^5]
    x2=point[:, 0]
    y2=point[:, 1]
    # feature = np.c_[np.ones(len(point)),x2**5,x2**4*y2,x2**3*y2**2,x2**2*y2**3,x2*y2**4,y2**5]
    feature = np.c_[np.ones(len(point)),x2**5,x2**4,y2,x2**4*y2,y2**2,x2**3,y2**3,x2**3*y2**2,y2**4,x2**2,x2**2*y2**3,x2,x2*y2**4,y2**5]
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return feature

# %% [markdown]
# ## define the linear regression function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature = $(1, f_1(x, y), \cdots, f_{k-1}(x, y)) \in \mathbb{R}^k$

# %%
def compute_linear_regression(theta, feature):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    value = np.inner(theta.T, feature)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define sigmoid function with input

# %% [markdown]
# - $z \in \mathbb{R}$

# %%
def sigmoid(z):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    value = 1/(1+np.exp(-1*z))

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define the logistic regression function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$

# %%
def compute_logistic_regression(theta, feature):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    value = sigmoid(compute_linear_regression(theta,feature))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define the residual function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$
# - label $= l \in \{0, 1\}^k$

# %%
def compute_residual(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    logh = np.log1p(compute_logistic_regression(theta, feature))
    logmh = np.log1p(1-compute_logistic_regression(theta,feature))
    residual = -1*label*logh-(1-label)*logmh

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return residual

# %% [markdown]
# ## define the loss function for the logistic regression

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$
# - label $= l \in \{0, 1\}^k$

# %%
def compute_loss(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    loss = np.sum(compute_residual(theta, feature, label))/feature.shape[0]

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return loss

# %% [markdown]
# ## define the gradient of the loss with respect to the model parameter $\theta$

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$
# - label $= l \in \{0, 1\}^k$

# %%
def compute_gradient(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    a = compute_logistic_regression(theta, feature)-label
    gradient = np.dot(feature.T, a)/feature.shape[0]

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return gradient

# %% [markdown]
# ## compute the accuracy of the prediction for point with a given model parameter

# %%
def compute_accuracy(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    #linear regression이 0이거나 logistic regression이 0.5가 되는 지점
    #accuracy = #correct / #point

    clr = compute_logistic_regression(theta, feature)
    accuracy = np.sum(np.where(clr>=0.5,1,0)==label)/feature.shape[0]

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return accuracy

# %% [markdown]
# ## initialize the gradient descent algorithm

# %%
data1_number_iteration   = 30000
data2_number_iteration   = 50000 

data1_learning_rate   = 0.1 
data2_learning_rate   = 0.1 

data1_number_feature    = 4
data2_number_feature    = 15

theta1  = np.zeros(data1_number_feature)
theta2  = np.zeros(data2_number_feature)

data1_loss_iteration  = np.zeros(data1_number_iteration)
data2_loss_iteration  = np.zeros(data2_number_iteration)

data1_accuracy_iteration    = np.zeros(data1_number_iteration)
data2_accuracy_iteration    = np.zeros(data2_number_iteration)

# %% [markdown]
# ## run the gradient descent algorithm to optimize the loss function with respect to the model parameter

# %%
for i in range(data1_number_iteration):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    #point에 뭐가 들어가야함?
    theta1      = theta1 - data1_learning_rate*compute_gradient(theta1, compute_feature1(data1_point),data1_label)
    loss1       = compute_loss(theta1, compute_feature1(data1_point), data1_label)
    accuracy1   = compute_accuracy(theta1, compute_feature1(data1_point), data1_label)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    data1_loss_iteration[i]     = loss1
    data1_accuracy_iteration[i] = accuracy1

data1_theta_optimal = theta1

# %%
for i in range(data2_number_iteration):
    
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    theta2      = theta2 - data2_learning_rate*compute_gradient(theta2, compute_feature2(data2_point),data2_label)
    loss2       = compute_loss(theta2, compute_feature2(data2_point), data2_label)
    accuracy2   = compute_accuracy(theta2, compute_feature2(data2_point), data2_label)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    data2_loss_iteration[i]     = loss2
    data2_accuracy_iteration[i] = accuracy2

data2_theta_optimal = theta2

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
def function_result_01():

    print("final loss for data1 = {:13.10f}".format(data1_loss_iteration[-1]))

# %%
def function_result_02():

    print("final loss for data2 = {:13.10f}".format(data2_loss_iteration[-1]))

# %%
def function_result_03():

    print("final accuracy for data1 = {:13.10f}".format(data1_accuracy_iteration[-1]))

# %%
def function_result_04():

    print("final accuracy for data2 = {:13.10f}".format(data2_accuracy_iteration[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6))
    plt.title('loss for data1')

    plt.plot(data1_loss_iteration, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')

    plt.tight_layout()
    plt.show()

# %%
def function_result_06():

    plt.figure(figsize=(8,6))
    plt.title('loss for data2')

    plt.plot(data2_loss_iteration, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')

    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('accuracy for data1')

    plt.plot(data1_accuracy_iteration, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('accuracy')

    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('accuracy for data2')

    plt.plot(data2_accuracy_iteration, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('accuracy')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## plot the linear regression values over the 2-dimensional Euclidean space and superimpose the training data

# %%
def function_result_09():

    plt.figure(figsize=(8,8)) # USE THIS VALUE for the size of the figure
    plt.title('linear regression values')
    
    min_x   = np.min(data1_point_x)
    max_x   = np.max(data1_point_x)
    min_y   = np.min(data1_point_y)
    max_y   = np.max(data1_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    Z= theta1[0]+theta1[1]*XX**2+theta1[2]*YY**2+theta1[3]*np.sqrt(2)*XX*YY
    plt.plot(data1_point_x_class_0, data1_point_y_class_0, 'o', color='blue', label='class = 0')
    plt.plot(data1_point_x_class_1, data1_point_y_class_1, 'o', color='red', label='class = 1')
    plt.contour(XX, YY, Z, levels=1, linewidths=1, colors='k')
    cp = plt.contourf(XX, YY, Z, 
                 levels = 100,cmap="RdBu_r"
                )
    plt.colorbar(cp)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.axis('equal')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def function_result_10():
    
    plt.figure(figsize=(8,8)) # USE THIS VALUE for the size of the figure
    plt.title('linear regression values')
    
    min_x   = np.min(data2_point_x)
    max_x   = np.max(data2_point_x)
    min_y   = np.min(data2_point_y)
    max_y   = np.max(data2_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #x2**5,x2**4,y2,x2**4*y2,y2**2,x2**3,y2**3,x2**3*y2**2,y2**4,x2**2,x2**2*y2**3,x2,x2*y2**4,y2**5

    Z= theta1[0]+theta2[1]*XX**5+theta2[2]*XX**4+theta2[3]*YY+theta2[4]*YY**2+theta2[5]*XX**3
    plt.plot(data2_point_x_class_0, data2_point_y_class_0, 'o', color='blue', label='class = 0')
    plt.plot(data2_point_x_class_1, data2_point_y_class_1, 'o', color='red', label='class = 1')
    plt.contour(XX, YY, compute_linear_regression(data2_theta_optimal,compute_feature2(data2_point)), levels=1, linewidths=1, colors='k')
    cp = plt.contourf(XX, YY, compute_linear_regression(data2_theta_optimal,compute_feature2(data2_point)), 
                 levels = 100,cmap="RdBu_r"
                )
    plt.colorbar(cp)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.axis('equal')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## plot the logistic regression values over the 2-dimensional Euclidean space

# %%
def function_result_11():

    plt.figure(figsize=(8,8)) # USE THIS VALUE for the size of the figure
    plt.title('logistic regression values')
    
    min_x   = np.min(data1_point_x)
    max_x   = np.max(data1_point_x)
    min_y   = np.min(data1_point_y)
    max_y   = np.max(data1_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    Z= theta1[0]+theta1[1]*XX**2+theta1[2]*YY**2+theta1[3]*np.sqrt(2)*XX*YY
    Sig=sigmoid(Z)
    plt.plot(data1_point_x_class_0, data1_point_y_class_0, 'o', color='blue', label='class = 0')
    plt.plot(data1_point_x_class_1, data1_point_y_class_1, 'o', color='red', label='class = 1')
    cp = plt.contourf(XX, YY, Sig, 
                 levels = 100,cmap="RdBu_r"
                )
    plt.colorbar(cp)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.axis('equal')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def function_result_12():
    
    plt.figure(figsize=(8,8)) # USE THIS VALUE for the size of the figure
    plt.title('logistic regression values')

    min_x   = np.min(data2_point_x)
    max_x   = np.max(data2_point_x)
    min_y   = np.min(data2_point_y)
    max_y   = np.max(data2_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.plot(data2_point_x_class_0, data2_point_y_class_0, 'o', color='blue', label='class = 0')
    plt.plot(data2_point_x_class_1, data2_point_y_class_1, 'o', color='red', label='class = 1')
    plt.contour(XX, YY, compute_logistic_regression(data2_theta_optimal,compute_feature2(data2_point)).reshape(-1,1), levels=1, linewidths=1, colors='k')
    cp = plt.contourf(XX, YY, compute_logistic_regression(data2_theta_optimal,compute_feature2(data2_point)).reshape(-1,1), 
                 levels = 100,cmap="RdBu_r"
                )
    plt.colorbar(cp)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.axis('equal')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ## results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
number_result = 12

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss for data1 = -0.6901088857
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss for data2 = -0.6868925404
# **************************************************
# ## [RESULT 03]
# **************************************************
# final accuracy for data1 =  0.9990000000
# **************************************************
# ## [RESULT 04]
# **************************************************
# final accuracy for data2 =  0.9970000000
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# **************************************************
# **************************************************
# ## [RESULT 08]
# **************************************************
# **************************************************
# ## [RESULT 09]
# **************************************************
# **************************************************
# ## [RESULT 10]
# **************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\rlatn\Desktop\4-1\machine learning\class\machine-learning\09\assignment_09.ipynb Cell 62' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000061?line=7'>8</a> print(title)
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000061?line=8'>9</a> print('**************************************************')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000061?line=9'>10</a> eval(name_function)
#
# File <string>:1, in <module>
#
# c:\Users\rlatn\Desktop\4-1\machine learning\class\machine-learning\09\assignment_09.ipynb Cell 53' in function_result_10()
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000052?line=19'>20</a> plt.plot(data2_point_x_class_0, data2_point_y_class_0, 'o', color='blue', label='class = 0')
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000052?line=20'>21</a> plt.plot(data2_point_x_class_1, data2_point_y_class_1, 'o', color='red', label='class = 1')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000052?line=21'>22</a> plt.contour(XX, YY, compute_linear_regression(data2_theta_optimal,compute_feature2(data2_point)), levels=1, linewidths=1, colors='k')
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000052?line=22'>23</a> cp = plt.contourf(XX, YY, compute_linear_regression(data2_theta_optimal,compute_feature2(data2_point)),
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000052?line=23'>24</a>              levels = 100,cmap="RdBu_r"
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000052?line=24'>25</a>             )
#      <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/09/assignment_09.ipynb#ch0000052?line=25'>26</a> plt.colorbar(cp)
#
# File c:\Users\rlatn\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py:2472, in contour(data, *args, **kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/pyplot.py?line=2469'>2470</a> @_copy_docstring_and_deprecators(Axes.contour)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/pyplot.py?line=2470'>2471</a> def contour(*args, data=None, **kwargs):
# -> <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/pyplot.py?line=2471'>2472</a>     __ret = gca().contour(
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/pyplot.py?line=2472'>2473</a>         *args, **({"data": data} if data is not None else {}),
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/pyplot.py?line=2473'>2474</a>         **kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/pyplot.py?line=2474'>2475</a>     if __ret._A is not None: sci(__ret)  # noqa
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/pyplot.py?line=2475'>2476</a>     return __ret
#
# File c:\Users\rlatn\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/__init__.py?line=1408'>1409</a> @functools.wraps(func)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/__init__.py?line=1409'>1410</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/__init__.py?line=1410'>1411</a>     if data is None:
# -> <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/__init__.py?line=1411'>1412</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/__init__.py?line=1413'>1414</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/__init__.py?line=1414'>1415</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/__init__.py?line=1415'>1416</a>                   or bound.kwargs.get(label_namer))
#
# File c:\Users\rlatn\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py:6301, in Axes.contour(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/axes/_axes.py?line=6291'>6292</a> """
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/axes/_axes.py?line=6292'>6293</a> Plot contour lines.
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/axes/_axes.py?line=6293'>6294</a>
#    (...)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/axes/_axes.py?line=6297'>6298</a> %(contour_doc)s
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/axes/_axes.py?line=6298'>6299</a> """
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/axes/_axes.py?line=6299'>6300</a> kwargs['filled'] = False
# -> <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/axes/_axes.py?line=6300'>6301</a> contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/axes/_axes.py?line=6301'>6302</a> self._request_autoscale_view()
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/axes/_axes.py?line=6302'>6303</a> return contours
#
# File c:\Users\rlatn\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\contour.py:812, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=807'>808</a>     self.origin = mpl.rcParams['image.origin']
#     <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=809'>810</a> self._transform = transform
# --> <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=811'>812</a> kwargs = self._process_args(*args, **kwargs)
#     <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=812'>813</a> self._process_levels()
#     <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=814'>815</a> self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\rlatn\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\contour.py:1441, in QuadContourSet._process_args(self, corner_mask, *args, **kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1437'>1438</a>     corner_mask = mpl.rcParams['contour.corner_mask']
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1438'>1439</a> self._corner_mask = corner_mask
# -> <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1440'>1441</a> x, y, z = self._contour_args(args, kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1442'>1443</a> _mask = ma.getmask(z)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1443'>1444</a> if _mask is ma.nomask or not _mask.any():
#
# File c:\Users\rlatn\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\contour.py:1480, in QuadContourSet._contour_args(self, args, kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1477'>1478</a>     args = args[1:]
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1478'>1479</a> elif Nargs <= 4:
# -> <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1479'>1480</a>     x, y, z = self._check_xyz(args[:3], kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1480'>1481</a>     args = args[3:]
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1481'>1482</a> else:
#
# File c:\Users\rlatn\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\contour.py:1508, in QuadContourSet._check_xyz(self, args, kwargs)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1504'>1505</a> z = ma.asarray(args[2], dtype=np.float64)
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1506'>1507</a> if z.ndim != 2:
# -> <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1507'>1508</a>     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1508'>1509</a> if z.shape[0] < 2 or z.shape[1] < 2:
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1509'>1510</a>     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    <a href='file:///c%3A/Users/rlatn/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/contour.py?line=1510'>1511</a>                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 1D
