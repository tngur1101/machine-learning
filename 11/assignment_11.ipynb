# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, color='blue')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# - feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    # center한개에 모든 feature의 distance를 계산해야함
    # feature은 n*m matrix고 center은 1*m matrix
    temp_dist = feature - center
    distance = np.sqrt(np.sum(temp_dist**2))
    print(distance)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return distance

# %% [markdown]
# ## compute centroid
# - feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    
    dist_feature = np.array(label_feature==label)
    list_feature = np.array(feature[dist_feature])
    centroid = np.mean(list_feature,axis=0)
    print(centroid)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return centroid

# %% [markdown]
# ## compute label
# - distance : $n \times k$, label_feature : $n \times 1$
# - $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    min_value = np.min(distance,axis=0)
    label_feature = min_value
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return label_feature

# %% [markdown]
# ## the number of clusters $K = 2$

# %%
number_cluster          = 2
number_iteration        = 2     # you can modify this value
loss_iteration_02       = np.zeros(number_iteration)
centroid_iteration_02   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_02        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(number_iteration):
    centroid_iteration_02 = compute_centroid(feature, label_feature_02, 0)
    centroid_iteration_02 = compute_centroid(feature, label_feature_02, 1)
    distance = compute_distance(feature,centroid_iteration_02)
    label_feature_02[i] = compute_label(distance)
    loss_iteration_02[i] = np.sum(distance**2, axis=0)/feature.shape[0]

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Out:
# [-3.14882863  0.35876311]
# [-2.49316325  0.69351568]
# 260.06819561186654
# [-3.14952947  0.34773305]
# [-2.49316325  0.69351568]
# 260.06819561186654

# %% [markdown]
# ## the number of clusters $K = 4$

# %%
number_cluster          = 4
number_iteration        = 2     # you can modify this value
loss_iteration_04       = np.zeros(number_iteration)
centroid_iteration_04   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_04        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(number_iteration):
    centroid_iteration_04 = compute_centroid(feature, label_feature_04, 0)
    centroid_iteration_04 = compute_centroid(feature, label_feature_04, 1)
    centroid_iteration_04 = compute_centroid(feature, label_feature_04, 2)
    centroid_iteration_04 = compute_centroid(feature, label_feature_04, 3)
    distance = compute_distance(feature,centroid_iteration_04)
    label_feature_04[i] = compute_label(distance)
    loss_iteration_04[i] = np.sum(distance**2, axis=0)/feature.shape[0]

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Out:
# [-2.82299595  0.93926137]
# [-2.8664603  -0.09852344]
# [-2.7646874  0.4490629]
# [-2.89741256  0.79116833]
# 259.9316044136953
# [-2.82299595  0.93926137]
# [-2.86680672 -0.12398075]
# [-2.7646874  0.4490629]
# [-2.89741256  0.79116833]
# 259.9316044136953

# %% [markdown]
# ## the number of clusters $K = 8$

# %%
number_cluster          = 8
number_iteration        = 2     # you can modify this value
loss_iteration_08       = np.zeros(number_iteration)
centroid_iteration_08   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_08        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(number_iteration):
    centroid_iteration_08 = compute_centroid(feature, label_feature_08, 0)
    centroid_iteration_08 = compute_centroid(feature, label_feature_08, 1)
    centroid_iteration_08 = compute_centroid(feature, label_feature_08, 2)
    centroid_iteration_08 = compute_centroid(feature, label_feature_08, 3)
    centroid_iteration_08 = compute_centroid(feature, label_feature_08, 4)
    centroid_iteration_08 = compute_centroid(feature, label_feature_08, 5)
    centroid_iteration_08 = compute_centroid(feature, label_feature_08, 6)
    centroid_iteration_08 = compute_centroid(feature, label_feature_08, 7)
    distance = compute_distance(feature,centroid_iteration_08)
    label_feature_08[i] = compute_label(distance)
    loss_iteration_08[i] = np.sum(distance**2, axis=0)/feature.shape[0]

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Out:
# [-2.55052835  0.35537253]
# [-3.1455035   0.35701388]
# [-2.74382421  1.48517091]
# [-3.54646837  0.42111873]
# [-2.24653096  0.27843512]
# [-2.45201164  0.67704813]
# [-3.41773371  0.07259994]
# [-2.56643596  0.471116  ]
# 259.92629931169586
# [-2.55052835  0.35537253]
# [-3.1455035   0.35701388]
# [-2.74382421  1.48517091]
# [-3.54646837  0.42111873]
# [-2.24653096  0.27843512]
# [-2.45201164  0.67704813]
# [-3.41773371  0.07259994]
# [-2.56462796  0.42349078]
# 259.9411012792774

# %% [markdown]
# ## the number of clusters $K = 16$

# %%
number_cluster          = 16
number_iteration        = 2     # you can modify this value
loss_iteration_16       = np.zeros(number_iteration)
centroid_iteration_16   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_16        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(number_iteration):
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 0)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 1)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 2)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 3)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 4)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 5)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 6)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 7)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 8)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 9)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 10)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 11)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 12)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 13)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 14)
    centroid_iteration_16 = compute_centroid(feature, label_feature_16, 15)
    distance = compute_distance(feature,centroid_iteration_16)
    label_feature_16[i] = compute_label(distance)
    loss_iteration_16[i] = np.sum(distance**2, axis=0)/feature.shape[0]

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Out:
# [-1.75503255 -0.42820405]
# [-2.01634011 -0.2115188 ]
# [-3.35026377  1.00989734]
# [-3.82253442  0.27769907]
# [-2.76870991  1.18634314]
# [-2.60327356  0.09889985]
# [-3.94051388 -1.49809071]
# [-3.17104686  0.17279674]
# [-2.31965038  1.49042974]
# [-2.81209816  1.04178777]
# [-2.73529282  1.78672593]
# [-3.24832649  0.89291884]
# [-2.6748076   0.65247758]
# [-1.8187306  1.4046399]
# [-3.25982314  0.10843106]
# [-3.53147517  0.43268653]
# 260.72032243713227
# [-1.75503255 -0.42820405]
# [-2.00627106 -0.2950719 ]
# [-3.35026377  1.00989734]
# [-3.82253442  0.27769907]
# [-2.76870991  1.18634314]
# [-2.60327356  0.09889985]
# [-3.94051388 -1.49809071]
# [-3.17104686  0.17279674]
# [-2.31965038  1.49042974]
# [-2.81209816  1.04178777]
# [-2.73529282  1.78672593]
# [-3.24832649  0.89291884]
# [-2.6748076   0.65247758]
# [-1.8187306  1.4046399]
# [-3.25982314  0.10843106]
# [-3.53147517  0.43268653]
# 260.72032243713227

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
def function_result_01():

    print("final loss (K=2) = {:13.10f}".format(loss_iteration_02[-1]))

# %%
def function_result_02():

    print("final loss (K=4) = {:13.10f}".format(loss_iteration_04[-1]))

# %%
def function_result_03():

    print("final loss (K=8) = {:13.10f}".format(loss_iteration_08[-1]))

# %%
def function_result_04():

    print("final loss (K=16) = {:13.10f}".format(loss_iteration_16[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=2)')

    plt.plot(loss_iteration_02, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=4)')

    plt.plot(loss_iteration_04, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=8)')

    plt.plot(loss_iteration_08, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=16)')

    plt.plot(loss_iteration_16, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_09():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_10():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_11():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_12():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_13():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_14():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_15():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_16():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
number_result = 16

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss (K=2) = 67.6354663688
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss (K=4) = 67.5644389731
# **************************************************
# ## [RESULT 03]
# **************************************************
# final loss (K=8) = 67.5693761343
# **************************************************
# ## [RESULT 04]
# **************************************************
# final loss (K=16) = 67.9750865317
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# **************************************************
# **************************************************
# ## [RESULT 08]
# **************************************************
# **************************************************
# ## [RESULT 09]
# **************************************************
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\rlatn\Desktop\4-1\machine learning\class\machine-learning\11\assignment_11.ipynb Cell 53' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/11/assignment_11.ipynb#ch0000051?line=7'>8</a> print(title)
#       <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/11/assignment_11.ipynb#ch0000051?line=8'>9</a> print('**************************************************')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/rlatn/Desktop/4-1/machine%20learning/class/machine-learning/11/assignment_11.ipynb#ch0000051?line=9'>10</a> eval(name_function)
#
# File <string>:1, in <module>
#
# NameError: name 'function_result_09' is not defined
