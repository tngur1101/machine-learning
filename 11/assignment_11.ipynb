# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, color='blue')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# - feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    # center한개에 모든 feature의 distance를 계산해야함
    # feature은 n*m matrix고 center은 1*m matrix
    temp_dist = (feature - center)**2
    # distance = np.power(temp_dist[:,0]+temp_dist[:,1], 0.5)
    distance = temp_dist[:,0]+temp_dist[:,1]
    
    # print( distance)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return distance

# %% [markdown]
# ## compute centroid
# - feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    # target=feature[np.where(label==label_feature)]
    # centroid=target.sum(axis=0)/len(target)
    c = np.where(label==label_feature)
    l=feature[c]
    s = l.sum(axis=0)
    centroid=s/len(l)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return centroid

# %% [markdown]
# ## compute label
# - distance : $n \times k$, label_feature : $n \times 1$
# - $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    #distance 중에 값이 최소가 되는 인덱스
    
    label_feature=np.argmin(distance,axis=1)
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return label_feature

# %% [markdown]
# ## the number of clusters $K = 2$

# %%
number_cluster          = 2
number_iteration        = 100     # you can modify this value
loss_iteration_02       = np.zeros(number_iteration)
centroid_iteration_02   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_02        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
distance  = np.zeros(shape=(number_data, number_cluster))
centroid = np.zeros(shape=(number_cluster, number_feature))

for i in range(number_iteration):
    loss_sum =0
    for j in range(number_cluster):
        if(len(feature[label_feature_02 == j])==0):
            centroid[j]=centroid_iteration_02[i-1][j]
        else:
            centroid[j] = compute_centroid(feature, label_feature_02, j)
        distance[:,j] = compute_distance(feature,centroid[j])
    
    centroid_iteration_02[i]=centroid
    
    # distance[i] = compute_distance(feature,centroid)
   
    label_feature_02 = compute_label(distance)
    loss_iteration_02[i] = sum(distance[range(feature.shape[0]),label_feature_02])/feature.shape[0]

    # for k in range(number_data):
        # label = label_feature_02[k]
        # point = distance[label][k]
        # loss_sum += point
        
    # loss_iteration_02[i] = loss_sum/feature.shape[0]
    
    # print(loss_iteration_02)

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 4$

# %%
number_cluster          = 4
number_iteration        = 100     # you can modify this value
loss_iteration_04       = np.zeros(number_iteration)
centroid_iteration_04   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_04        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
distance  = np.zeros(shape=(number_data, number_cluster))
centroid = np.zeros(shape=(number_cluster, number_feature))

for i in range(number_iteration):
    loss_sum =0
    for j in range(number_cluster):
        if(len(feature[label_feature_04 == j])==0):
            centroid[j]=centroid_iteration_04[i-1][j]
        else:
            centroid[j] = compute_centroid(feature, label_feature_04, j)
        distance[:,j] = compute_distance(feature,centroid[j])
    
    centroid_iteration_04[i]=centroid
    
    # distance[i] = compute_distance(feature,centroid)
   
    label_feature_04 = compute_label(distance)
    loss_iteration_04[i] = sum(distance[range(feature.shape[0]),label_feature_04])/feature.shape[0]

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 8$

# %%
number_cluster          = 8
number_iteration        = 100     # you can modify this value
loss_iteration_08       = np.zeros(number_iteration)
centroid_iteration_08   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_08        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
distance  = np.zeros(shape=(number_data, number_cluster))
centroid = np.zeros(shape=(number_cluster, number_feature))

for i in range(number_iteration):
    loss_sum =0
    for j in range(number_cluster):
        if(len(feature[label_feature_08 == j])==0):
            centroid[j]=centroid_iteration_08[i-1][j]
        else:
            centroid[j] = compute_centroid(feature, label_feature_08, j)
        distance[:,j] = compute_distance(feature,centroid[j])
    
    centroid_iteration_08[i]=centroid
    
    # distance[i] = compute_distance(feature,centroid)
   
    label_feature_08 = compute_label(distance)
    loss_iteration_08[i] = sum(distance[range(feature.shape[0]),label_feature_08])/feature.shape[0]
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 16$

# %%
number_cluster          = 16
number_iteration        = 100     # you can modify this value
loss_iteration_16       = np.zeros(number_iteration)
centroid_iteration_16   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_16        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
distance  = np.zeros(shape=(number_data, number_cluster))
centroid = np.zeros(shape=(number_cluster, number_feature))

for i in range(number_iteration):
    loss_sum =0
    for j in range(number_cluster):
        if(len(feature[label_feature_16 == j])==0):
            centroid[j]=centroid_iteration_16[i-1][j]
        else:
            centroid[j] = compute_centroid(feature, label_feature_16, j)
        distance[:,j] = compute_distance(feature,centroid[j])
    
    centroid_iteration_16[i]=centroid
    
    # distance[i] = compute_distance(feature,centroid)
   
    label_feature_16 = compute_label(distance)
    loss_iteration_16[i] = sum(distance[range(feature.shape[0]),label_feature_16])/feature.shape[0]

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
def function_result_01():

    print("final loss (K=2) = {:13.10f}".format(loss_iteration_02[-1]))

# %%
def function_result_02():

    print("final loss (K=4) = {:13.10f}".format(loss_iteration_04[-1]))

# %%
def function_result_03():

    print("final loss (K=8) = {:13.10f}".format(loss_iteration_08[-1]))

# %%
def function_result_04():

    print("final loss (K=16) = {:13.10f}".format(loss_iteration_16[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=2)')

    plt.plot(loss_iteration_02, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=4)')

    plt.plot(loss_iteration_04, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=8)')

    plt.plot(loss_iteration_08, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=16)')

    plt.plot(loss_iteration_16, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_09():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    # for i in range(number_cluster):
    #     plt.plot(centroid_iteration[:, i, 0], centroid_iteration[:, i, 1], label = "cluster {}".format(i + 1))
    #     plt.plot(centroid_iteration[0, i, 0], centroid_iteration[0, i, 1], 'o', color = "blue")
    #     plt.plot(centroid_iteration[100 - 1, i, 0], centroid_iteration[100 - 1, i, 1], 's', color = "red")

    # plt.legend()
    # plt.tight_layout()
    # plt.show()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_10():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_11():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_12():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_13():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    for i in range(number_cluster):
        cluster_value = i
        bool_feature = np.array(label_feature_02 == cluster_value).flatten()
        sect_feature = np.array(feature[bool_feature])
        plt.plot(sect_feature[:, 0], sect_feature[:, 1], 'o', label = "cluster {}".format(i + 1))
        

    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_14():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    for i in range(number_cluster):
        cluster_value = i
        bool_feature = np.array(label_feature_04 == cluster_value).flatten()
        sect_feature = np.array(feature[bool_feature])
        plt.plot(sect_feature[:, 0], sect_feature[:, 1], 'o', label = "cluster {}".format(i + 1))
        

    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_15():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    for i in range(number_cluster):
        cluster_value = i
        bool_feature = np.array(label_feature_08 == cluster_value).flatten()
        sect_feature = np.array(feature[bool_feature])
        plt.plot(sect_feature[:, 0], sect_feature[:, 1], 'o', label = "cluster {}".format(i + 1))
        

    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_16():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    for i in range(number_cluster):
        cluster_value = i
        bool_feature = np.array(label_feature_16 == cluster_value).flatten()
        sect_feature = np.array(feature[bool_feature])
        plt.plot(sect_feature[:, 0], sect_feature[:, 1], 'o', label = "cluster {}".format(i + 1))
        

    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
number_result = 16

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss (K=2) = 31.1126288111
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss (K=4) = 10.5831291650
# **************************************************
# ## [RESULT 03]
# **************************************************
# final loss (K=8) =  5.8860119262
# **************************************************
# ## [RESULT 04]
# **************************************************
# final loss (K=16) =  3.1004014989
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# **************************************************
# **************************************************
# ## [RESULT 08]
# **************************************************
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# **************************************************
# ## [RESULT 09]
# **************************************************
# **************************************************
# ## [RESULT 10]
# **************************************************
# **************************************************
# ## [RESULT 11]
# **************************************************
# **************************************************
# ## [RESULT 12]
# **************************************************
# **************************************************
# ## [RESULT 13]
# **************************************************
# **************************************************
# ## [RESULT 14]
# **************************************************
# **************************************************
# ## [RESULT 15]
# **************************************************
# **************************************************
# ## [RESULT 16]
# **************************************************
